# %% [markdown]
# # 프로젝트 4 : CNN으로 패션 아이템 구분
#
# - 일반적 신경망은 다양한 형태의 입력에 대한 확장성이 떨어짐
# - ex. 신발이 가운데 있는 것으로 학습하다 신발이 한쪽으로 치우치면 성능 저하
# - 특징 추출 가중치 가운데 집중하도록 학습되었기 때문

# %% [markdown]
# ### CNN
#
# - 사물이 조금만 치우쳐도 인식하지 못하던 인공 신경망 문제를 이미지 전체를 필터링 하는 방식으로 해결
#
# - 이미지를 추출하는 필터 학습, 필터 하나가 작은 신경망이 됨
# - 구성 : 컨볼루션 계층, 풀링 계층, 최종 분류용 일반 신경망
#
# - 컨볼루션 : 특징 추출 위해 단계별 다양한 필터를 적용하고, 필터 적용시마다 이미지 왼쪽 위에서 오른쪽 아래까지 밀면서 곱하고 더하는 작업
# - 컨볼루션 필터 = 커널 : 이미지에 겹치는 작은 필터 3X# 또는 5X5 사용
# - 풀링계층 : 필터를 거친 여러 특징 중 가장 중요한 특징 하나 골라냄(평균이나 최대값 사용)
# - 스트라이드 : 필터를 몇칸씩 건너뛰며 적용할 지를 조절 하는 값
# - 특징 맵 : 컨볼루션 거쳐 나온 새로운 이미지

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device('cuda' if USE_CUDA else 'cpu')

# %%
EPOCHS = 40
BATCH_SIZE = 64

# %% [markdown]
# # 데이터셋 불러오기

# %%
train_loader = torch.utils.data.DataLoader(
        datasets.MNIST('./.data',
                      train=True,
                      download=True,
                      transform=transforms.Compose([
                          transforms.RandomHorizontalFlip(),
                          transforms.ToTensor(),
                          transforms.Normalize((0.1307,), (0.3081,))
                          
                      ])),
        batch_size=BATCH_SIZE, shuffle=True)

test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('./.data',
                      train=False,
                      transform=transforms.Compose([
                          transforms.ToTensor(),
                          transforms.Normalize((0.1307,), (0.3081,))
                      ])),
        batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# # cnn 신경망 설계

# %%
class Net(nn.Module) :
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)  # 채널수 1(흑백), 10개
                                            # 특징맵, 커널 크기 5X5, 숫자하나 정사각형 간주
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)
        
    # 풀링 계층    
    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
model = Net().to(DEVICE)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

# %% [markdown]
# # 학습하기

# %%
def train(model, train_loader, optimizer, epoch) :
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader) :
        data, target = data.to(DEVICE), target.to(DEVICE)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        
        if batch_idx % 200 == 0:
            print('Train Epoch: {} [{}/{}  ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(data), len(train_loader.dataset),
                100.*batch_idx / len(train_loader), loss.item()))

# %% [markdown]
# # 테스트하기

# %%
def evaluate(model, test_loader) :
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader :
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data)
            
            # 배치 오차를 생산
            test_loss += F.cross_entropy(output, target,
                                        reduction = 'sum').item()
            
            # 가장 높은 값을 가진 인덱스가 바로 예측값
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
            
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %% [markdown]
# # 실행
#
# - 앞 프로젝트와 정확도 비교

# %%
for epoch in range(1, EPOCHS + 1) :
    train(model, train_loader, optimizer, epoch)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print('[{}] Test Loss: {:.4f}, Accuracy: {:.2f}%'.format(
           epoch, test_loss, test_accuracy))
# Out:
# Train Epoch: 1 [0/60000  (0%)]	Loss: 2.316802
# Train Epoch: 1 [12800/60000  (21%)]	Loss: 1.445771
# Train Epoch: 1 [25600/60000  (43%)]	Loss: 1.292153
# Train Epoch: 1 [38400/60000  (64%)]	Loss: 0.919689
# Train Epoch: 1 [51200/60000  (85%)]	Loss: 0.874145
# [1] Test Loss: 0.4472, Accuracy: 86.20%
# Train Epoch: 2 [0/60000  (0%)]	Loss: 0.682692
# Train Epoch: 2 [12800/60000  (21%)]	Loss: 0.823187
# Train Epoch: 2 [25600/60000  (43%)]	Loss: 0.584783
# Train Epoch: 2 [38400/60000  (64%)]	Loss: 0.457481
# Train Epoch: 2 [51200/60000  (85%)]	Loss: 0.399676
# [2] Test Loss: 0.3197, Accuracy: 90.05%
# Train Epoch: 3 [0/60000  (0%)]	Loss: 0.591260
# Train Epoch: 3 [12800/60000  (21%)]	Loss: 0.664857
# Train Epoch: 3 [25600/60000  (43%)]	Loss: 0.456080
# Train Epoch: 3 [38400/60000  (64%)]	Loss: 0.479529
# Train Epoch: 3 [51200/60000  (85%)]	Loss: 0.641049
# [3] Test Loss: 0.2331, Accuracy: 93.47%
# Train Epoch: 4 [0/60000  (0%)]	Loss: 0.304638
# Train Epoch: 4 [12800/60000  (21%)]	Loss: 0.620368
# Train Epoch: 4 [25600/60000  (43%)]	Loss: 0.638957
# Train Epoch: 4 [38400/60000  (64%)]	Loss: 0.454301
# Train Epoch: 4 [51200/60000  (85%)]	Loss: 0.558550
# [4] Test Loss: 0.1917, Accuracy: 94.57%
# Train Epoch: 5 [0/60000  (0%)]	Loss: 0.528237
# Train Epoch: 5 [12800/60000  (21%)]	Loss: 0.389631
# Train Epoch: 5 [25600/60000  (43%)]	Loss: 0.273756
# Train Epoch: 5 [38400/60000  (64%)]	Loss: 0.475897
# Train Epoch: 5 [51200/60000  (85%)]	Loss: 0.429911
# [5] Test Loss: 0.1621, Accuracy: 95.28%
# Train Epoch: 6 [0/60000  (0%)]	Loss: 0.255870
# Train Epoch: 6 [12800/60000  (21%)]	Loss: 0.522485
# Train Epoch: 6 [25600/60000  (43%)]	Loss: 0.460126
# Train Epoch: 6 [38400/60000  (64%)]	Loss: 0.374193
# Train Epoch: 6 [51200/60000  (85%)]	Loss: 0.266722
# [6] Test Loss: 0.1491, Accuracy: 95.62%
# Train Epoch: 7 [0/60000  (0%)]	Loss: 0.313366
# Train Epoch: 7 [12800/60000  (21%)]	Loss: 0.252260
# Train Epoch: 7 [25600/60000  (43%)]	Loss: 0.740547
# Train Epoch: 7 [38400/60000  (64%)]	Loss: 0.493155
# Train Epoch: 7 [51200/60000  (85%)]	Loss: 0.217927
# [7] Test Loss: 0.1336, Accuracy: 95.89%
# Train Epoch: 8 [0/60000  (0%)]	Loss: 0.216495
# Train Epoch: 8 [12800/60000  (21%)]	Loss: 0.419915
# Train Epoch: 8 [25600/60000  (43%)]	Loss: 0.473564
# Train Epoch: 8 [38400/60000  (64%)]	Loss: 0.223208
# Train Epoch: 8 [51200/60000  (85%)]	Loss: 0.486617
# [8] Test Loss: 0.1220, Accuracy: 96.27%
# Train Epoch: 9 [0/60000  (0%)]	Loss: 0.573134
# Train Epoch: 9 [12800/60000  (21%)]	Loss: 0.345884
# Train Epoch: 9 [25600/60000  (43%)]	Loss: 0.283594
# Train Epoch: 9 [38400/60000  (64%)]	Loss: 0.293070
# Train Epoch: 9 [51200/60000  (85%)]	Loss: 0.457932
# [9] Test Loss: 0.1241, Accuracy: 96.27%
# Train Epoch: 10 [0/60000  (0%)]	Loss: 0.409962
# Train Epoch: 10 [12800/60000  (21%)]	Loss: 0.414883
# Train Epoch: 10 [25600/60000  (43%)]	Loss: 0.575494
# Train Epoch: 10 [38400/60000  (64%)]	Loss: 0.509998
# Train Epoch: 10 [51200/60000  (85%)]	Loss: 0.224711
# [10] Test Loss: 0.1115, Accuracy: 96.65%
# Train Epoch: 11 [0/60000  (0%)]	Loss: 0.151726
# Train Epoch: 11 [12800/60000  (21%)]	Loss: 0.135796
# Train Epoch: 11 [25600/60000  (43%)]	Loss: 0.259200
# Train Epoch: 11 [38400/60000  (64%)]	Loss: 0.263944
# Train Epoch: 11 [51200/60000  (85%)]	Loss: 0.408496
# [11] Test Loss: 0.1092, Accuracy: 96.57%
# Train Epoch: 12 [0/60000  (0%)]	Loss: 0.269334
# Train Epoch: 12 [12800/60000  (21%)]	Loss: 0.296744
# Train Epoch: 12 [25600/60000  (43%)]	Loss: 0.291366
# Train Epoch: 12 [38400/60000  (64%)]	Loss: 0.433475
# Train Epoch: 12 [51200/60000  (85%)]	Loss: 0.362833
# [12] Test Loss: 0.1004, Accuracy: 96.89%
# Train Epoch: 13 [0/60000  (0%)]	Loss: 0.210973
# Train Epoch: 13 [12800/60000  (21%)]	Loss: 0.369171
# Train Epoch: 13 [25600/60000  (43%)]	Loss: 0.150655
# Train Epoch: 13 [38400/60000  (64%)]	Loss: 0.452988
# Train Epoch: 13 [51200/60000  (85%)]	Loss: 0.274809
# [13] Test Loss: 0.1049, Accuracy: 96.78%
# Train Epoch: 14 [0/60000  (0%)]	Loss: 0.411822
# Train Epoch: 14 [12800/60000  (21%)]	Loss: 0.305900
# Train Epoch: 14 [25600/60000  (43%)]	Loss: 0.130151
# Train Epoch: 14 [38400/60000  (64%)]	Loss: 0.370643
# Train Epoch: 14 [51200/60000  (85%)]	Loss: 0.435149
# [14] Test Loss: 0.1006, Accuracy: 96.86%
# Train Epoch: 15 [0/60000  (0%)]	Loss: 0.403255
# Train Epoch: 15 [12800/60000  (21%)]	Loss: 0.369337
# Train Epoch: 15 [25600/60000  (43%)]	Loss: 0.211751
# Train Epoch: 15 [38400/60000  (64%)]	Loss: 0.267686
# Train Epoch: 15 [51200/60000  (85%)]	Loss: 0.309413
# [15] Test Loss: 0.0975, Accuracy: 97.00%
# Train Epoch: 16 [0/60000  (0%)]	Loss: 0.308745
# Train Epoch: 16 [12800/60000  (21%)]	Loss: 0.257925
# Train Epoch: 16 [25600/60000  (43%)]	Loss: 0.204286
# Train Epoch: 16 [38400/60000  (64%)]	Loss: 0.441201
# Train Epoch: 16 [51200/60000  (85%)]	Loss: 0.322340
# [16] Test Loss: 0.0919, Accuracy: 97.13%
# Train Epoch: 17 [0/60000  (0%)]	Loss: 0.092624
# Train Epoch: 17 [12800/60000  (21%)]	Loss: 0.169299
# Train Epoch: 17 [25600/60000  (43%)]	Loss: 0.401546
# Train Epoch: 17 [38400/60000  (64%)]	Loss: 0.288398
# Train Epoch: 17 [51200/60000  (85%)]	Loss: 0.174123
# [17] Test Loss: 0.0929, Accuracy: 97.17%
# Train Epoch: 18 [0/60000  (0%)]	Loss: 0.326628
# Train Epoch: 18 [12800/60000  (21%)]	Loss: 0.151943
# Train Epoch: 18 [25600/60000  (43%)]	Loss: 0.292652
# Train Epoch: 18 [38400/60000  (64%)]	Loss: 0.387648
# Train Epoch: 18 [51200/60000  (85%)]	Loss: 0.281899
# [18] Test Loss: 0.0873, Accuracy: 97.29%
# Train Epoch: 19 [0/60000  (0%)]	Loss: 0.272862
# Train Epoch: 19 [12800/60000  (21%)]	Loss: 0.206433
# Train Epoch: 19 [25600/60000  (43%)]	Loss: 0.358588
# Train Epoch: 19 [38400/60000  (64%)]	Loss: 0.291094
# Train Epoch: 19 [51200/60000  (85%)]	Loss: 0.351286
# [19] Test Loss: 0.0850, Accuracy: 97.38%
# Train Epoch: 20 [0/60000  (0%)]	Loss: 0.262222
# Train Epoch: 20 [12800/60000  (21%)]	Loss: 0.216385
# Train Epoch: 20 [25600/60000  (43%)]	Loss: 0.183237
# Train Epoch: 20 [38400/60000  (64%)]	Loss: 0.653237
# Train Epoch: 20 [51200/60000  (85%)]	Loss: 0.119266
# [20] Test Loss: 0.0849, Accuracy: 97.34%
# Train Epoch: 21 [0/60000  (0%)]	Loss: 0.591912
# Train Epoch: 21 [12800/60000  (21%)]	Loss: 0.236970
# Train Epoch: 21 [25600/60000  (43%)]	Loss: 0.642248
# Train Epoch: 21 [38400/60000  (64%)]	Loss: 0.337696
# Train Epoch: 21 [51200/60000  (85%)]	Loss: 0.233505
# [21] Test Loss: 0.0882, Accuracy: 97.23%
# Train Epoch: 22 [0/60000  (0%)]	Loss: 0.296539
# Train Epoch: 22 [12800/60000  (21%)]	Loss: 0.355500
# Train Epoch: 22 [25600/60000  (43%)]	Loss: 0.188533
# Train Epoch: 22 [38400/60000  (64%)]	Loss: 0.219284
# Train Epoch: 22 [51200/60000  (85%)]	Loss: 0.222329
# [22] Test Loss: 0.0837, Accuracy: 97.39%
# Train Epoch: 23 [0/60000  (0%)]	Loss: 0.104225
# Train Epoch: 23 [12800/60000  (21%)]	Loss: 0.354700
# Train Epoch: 23 [25600/60000  (43%)]	Loss: 0.299838
# Train Epoch: 23 [38400/60000  (64%)]	Loss: 0.250423
# Train Epoch: 23 [51200/60000  (85%)]	Loss: 0.343323
# [23] Test Loss: 0.0854, Accuracy: 97.16%
# Train Epoch: 24 [0/60000  (0%)]	Loss: 0.329407
# Train Epoch: 24 [12800/60000  (21%)]	Loss: 0.381413
# Train Epoch: 24 [25600/60000  (43%)]	Loss: 0.214658
# Train Epoch: 24 [38400/60000  (64%)]	Loss: 0.210237
# Train Epoch: 24 [51200/60000  (85%)]	Loss: 0.376258
# [24] Test Loss: 0.0825, Accuracy: 97.38%
# Train Epoch: 25 [0/60000  (0%)]	Loss: 0.270758
# Train Epoch: 25 [12800/60000  (21%)]	Loss: 0.377407
# Train Epoch: 25 [25600/60000  (43%)]	Loss: 0.397403
# Train Epoch: 25 [38400/60000  (64%)]	Loss: 0.355734
# Train Epoch: 25 [51200/60000  (85%)]	Loss: 0.098308
# [25] Test Loss: 0.0814, Accuracy: 97.51%
# Train Epoch: 26 [0/60000  (0%)]	Loss: 0.230705
# Train Epoch: 26 [12800/60000  (21%)]	Loss: 0.453129
# Train Epoch: 26 [25600/60000  (43%)]	Loss: 0.345226
# Train Epoch: 26 [38400/60000  (64%)]	Loss: 0.409316
# Train Epoch: 26 [51200/60000  (85%)]	Loss: 0.131757
# [26] Test Loss: 0.0794, Accuracy: 97.57%
# Train Epoch: 27 [0/60000  (0%)]	Loss: 0.183179
# Train Epoch: 27 [12800/60000  (21%)]	Loss: 0.312936
# Train Epoch: 27 [25600/60000  (43%)]	Loss: 0.416543
# Train Epoch: 27 [38400/60000  (64%)]	Loss: 0.267759
# Train Epoch: 27 [51200/60000  (85%)]	Loss: 0.169351
# [27] Test Loss: 0.0786, Accuracy: 97.68%
# Train Epoch: 28 [0/60000  (0%)]	Loss: 0.246701
# Train Epoch: 28 [12800/60000  (21%)]	Loss: 0.117574
# Train Epoch: 28 [25600/60000  (43%)]	Loss: 0.144410
# Train Epoch: 28 [38400/60000  (64%)]	Loss: 0.304354
# Train Epoch: 28 [51200/60000  (85%)]	Loss: 0.189145
# [28] Test Loss: 0.0759, Accuracy: 97.56%
# Train Epoch: 29 [0/60000  (0%)]	Loss: 0.485822
# Train Epoch: 29 [12800/60000  (21%)]	Loss: 0.128733
# Train Epoch: 29 [25600/60000  (43%)]	Loss: 0.335015
# Train Epoch: 29 [38400/60000  (64%)]	Loss: 0.360688
# Train Epoch: 29 [51200/60000  (85%)]	Loss: 0.235643
# [29] Test Loss: 0.0782, Accuracy: 97.57%
# Train Epoch: 30 [0/60000  (0%)]	Loss: 0.191932
# Train Epoch: 30 [12800/60000  (21%)]	Loss: 0.123715
# Train Epoch: 30 [25600/60000  (43%)]	Loss: 0.309732
# Train Epoch: 30 [38400/60000  (64%)]	Loss: 0.234851
# Train Epoch: 30 [51200/60000  (85%)]	Loss: 0.242304
# [30] Test Loss: 0.0783, Accuracy: 97.60%
# Train Epoch: 31 [0/60000  (0%)]	Loss: 0.143128
# Train Epoch: 31 [12800/60000  (21%)]	Loss: 0.237455
# Train Epoch: 31 [25600/60000  (43%)]	Loss: 0.343660
# Train Epoch: 31 [38400/60000  (64%)]	Loss: 0.169340
# Train Epoch: 31 [51200/60000  (85%)]	Loss: 0.356946
# [31] Test Loss: 0.0761, Accuracy: 97.61%
# Train Epoch: 32 [0/60000  (0%)]	Loss: 0.333277
# Train Epoch: 32 [12800/60000  (21%)]	Loss: 0.105167
# Train Epoch: 32 [25600/60000  (43%)]	Loss: 0.221693
# Train Epoch: 32 [38400/60000  (64%)]	Loss: 0.287967
# Train Epoch: 32 [51200/60000  (85%)]	Loss: 0.346450
# [32] Test Loss: 0.0734, Accuracy: 97.73%
# Train Epoch: 33 [0/60000  (0%)]	Loss: 0.127576
# Train Epoch: 33 [12800/60000  (21%)]	Loss: 0.163268
# Train Epoch: 33 [25600/60000  (43%)]	Loss: 0.138100
# Train Epoch: 33 [38400/60000  (64%)]	Loss: 0.248416
# Train Epoch: 33 [51200/60000  (85%)]	Loss: 0.102574
# [33] Test Loss: 0.0741, Accuracy: 97.83%
# Train Epoch: 34 [0/60000  (0%)]	Loss: 0.298532
# Train Epoch: 34 [12800/60000  (21%)]	Loss: 0.172376
# Train Epoch: 34 [25600/60000  (43%)]	Loss: 0.369803
# Train Epoch: 34 [38400/60000  (64%)]	Loss: 0.304820
# Train Epoch: 34 [51200/60000  (85%)]	Loss: 0.121575
# [34] Test Loss: 0.0721, Accuracy: 97.80%
# Train Epoch: 35 [0/60000  (0%)]	Loss: 0.187784
# Train Epoch: 35 [12800/60000  (21%)]	Loss: 0.212510
# Train Epoch: 35 [25600/60000  (43%)]	Loss: 0.342285
# Train Epoch: 35 [38400/60000  (64%)]	Loss: 0.389978
# Train Epoch: 35 [51200/60000  (85%)]	Loss: 0.120819
# [35] Test Loss: 0.0697, Accuracy: 97.84%
# Train Epoch: 36 [0/60000  (0%)]	Loss: 0.226261
# Train Epoch: 36 [12800/60000  (21%)]	Loss: 0.252414
# Train Epoch: 36 [25600/60000  (43%)]	Loss: 0.258849
# Train Epoch: 36 [38400/60000  (64%)]	Loss: 0.332495
# Train Epoch: 36 [51200/60000  (85%)]	Loss: 0.160663
# [36] Test Loss: 0.0747, Accuracy: 97.58%
# Train Epoch: 37 [0/60000  (0%)]	Loss: 0.275475
# Train Epoch: 37 [12800/60000  (21%)]	Loss: 0.324300
# Train Epoch: 37 [25600/60000  (43%)]	Loss: 0.091643
# Train Epoch: 37 [38400/60000  (64%)]	Loss: 0.169020
# Train Epoch: 37 [51200/60000  (85%)]	Loss: 0.327342
# [37] Test Loss: 0.0743, Accuracy: 97.65%
# Train Epoch: 38 [0/60000  (0%)]	Loss: 0.244739
# Train Epoch: 38 [12800/60000  (21%)]	Loss: 0.173868
# Train Epoch: 38 [25600/60000  (43%)]	Loss: 0.123783
# Train Epoch: 38 [38400/60000  (64%)]	Loss: 0.233417
# Train Epoch: 38 [51200/60000  (85%)]	Loss: 0.240632
# [38] Test Loss: 0.0723, Accuracy: 97.75%
# Train Epoch: 39 [0/60000  (0%)]	Loss: 0.357940
# Train Epoch: 39 [12800/60000  (21%)]	Loss: 0.076888
# Train Epoch: 39 [25600/60000  (43%)]	Loss: 0.145847
# Train Epoch: 39 [38400/60000  (64%)]	Loss: 0.271262
# Train Epoch: 39 [51200/60000  (85%)]	Loss: 0.113213
# [39] Test Loss: 0.0682, Accuracy: 97.80%
# Train Epoch: 40 [0/60000  (0%)]	Loss: 0.155703
# Train Epoch: 40 [12800/60000  (21%)]	Loss: 0.249235
# Train Epoch: 40 [25600/60000  (43%)]	Loss: 0.098024
# Train Epoch: 40 [38400/60000  (64%)]	Loss: 0.394791
# Train Epoch: 40 [51200/60000  (85%)]	Loss: 0.413536
# [40] Test Loss: 0.0694, Accuracy: 97.77%
